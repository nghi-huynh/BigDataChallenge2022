# %%
import pandas as pd
import functools as fn 
import numpy as np

# %%
# !git clone https://github.com/nghi-huynh/BigDataChallenge2022.git
# Out:
# Cloning into 'BigDataChallenge2022'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 72 (delta 22), reused 57 (delta 10), pack-reused 0
# Unpacking objects: 100% (72/72), done.

# %%
# !mv /content/BigDataChallenge2022/raw_data .
# !mv /content/BigDataChallenge2022/merged_data .
# !rm -r /content/BigDataChallenge2022

# %% [markdown]
# ## Helper functions

# %%
# melt dataframes based on id columns
def melt(df,id_vars, var_name, value_name):
  tmp = df.melt(id_vars=id_vars,var_name=var_name,value_name=value_name)
  return tmp

# %%
# drop columns and melt dataframe 
def preprocessing(df, cols_drop, melt_vars):
  tmp = df.drop(cols_drop, axis=1)
  tmp = melt(tmp, melt_vars[0], melt_vars[1], melt_vars[2])
  return tmp

# %%
# merge data frames
# specify left on, right on, and how
def merge_data(dataframes, left_on, right_on, how):
  tmp = fn.reduce(lambda  left,right: pd.merge(left,right,left_on=left_on,
                                                   right_on=right_on,
                                                   how=how), dataframes)
                                            
  return tmp

# %% [markdown]
# Since our raw data have two types of structure, I want to separate them into 2 parts and merge them based on their current structure first. Then, I re-structured the merged dataframes and merged all of them together.

# %% [markdown]
# ## Merge deaths related to mental disorders, suicide rate

# %% [markdown]
# ### Load and check

# %%
mental_substance_death = pd.read_csv("/content/raw_data/death-rates-from-mental-and-substance-disorders-by-age.csv")

# %%
mental_substance_death.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: Under 5 (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: 70+ years (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: 5-14 years (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: 15-49 years (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: 50-69 years (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: All Ages (Rate)'],
#       dtype='object')

# %%
mental_substance_death.isnull().sum()
# Out:
# Entity                                                                                      0
# Code                                                                                      980
# Year                                                                                        0
# Deaths - Mental and substance use disorders - Sex: Both - Age: Under 5 (Rate)             312
# Deaths - Mental and substance use disorders - Sex: Both - Age: 70+ years (Rate)           312
# Deaths - Mental and substance use disorders - Sex: Both - Age: 5-14 years (Rate)            0
# Deaths - Mental and substance use disorders - Sex: Both - Age: 15-49 years (Rate)           0
# Deaths - Mental and substance use disorders - Sex: Both - Age: 50-69 years (Rate)         312
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)      0
# Deaths - Mental and substance use disorders - Sex: Both - Age: All Ages (Rate)              0
# dtype: int64

# %%
# Select columns we want to keep
cols = ['Entity','Year','Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)']

# %%
mental_substance_death_final = mental_substance_death[cols]

# %%
mental_substance_death_final
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6463     Zimbabwe  2013
# 6464     Zimbabwe  2014
# 6465     Zimbabwe  2015
# 6466     Zimbabwe  2016
# 6467     Zimbabwe  2017
#
#       Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)
# 0                                              0.144067
# 1                                              0.140653
# 2                                              0.135279
# 3                                              0.133047
# 4                                              0.130073
# ...                                                 ...
# 6463                                           1.379243
# 6464                                           1.398058
# 6465                                           1.413464
# 6466                                           1.445058
# 6467                                           1.470020
#
# [6468 rows x 3 columns]

# %%
mental_substance_death_final.isnull().sum()
# Out:
# Entity                                                                                    0
# Year                                                                                      0
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)    0
# dtype: int64

# %%
countries_a = list(mental_substance_death_final['Entity'].unique())
len(countries_a)
# Out:
# 231

# %%
self_harm_death = pd.read_csv("/content/raw_data/share-deaths-suicide.csv")
self_harm_death = self_harm_death.drop(["Code"], axis=1)
self_harm_death
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 8095     Zimbabwe  2015
# 8096     Zimbabwe  2016
# 8097     Zimbabwe  2017
# 8098     Zimbabwe  2018
# 8099     Zimbabwe  2019
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)
# 0                                              0.381465
# 1                                              0.388646
# 2                                              0.409441
# 3                                              0.418030
# 4                                              0.409779
# ...                                                 ...
# 8095                                           1.676438
# 8096                                           1.747906
# 8097                                           1.804474
# 8098                                           1.870430
# 8099                                           1.893108
#
# [8100 rows x 3 columns]

# %%
countries_b = list(self_harm_death['Entity'].unique())
len(countries_b)
# Out:
# 270

# %%
self_harm_death.isnull().sum()
# Out:
# Entity                                                      0
# Year                                                        0
# Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)    0
# dtype: int64

# %%
mental_death = pd.read_csv("/content/raw_data/share-with-mental-and-substance-disorders.csv")
mental_death = mental_death.drop(["Code"], axis=1)
mental_death
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6895     Zimbabwe  2015
# 6896     Zimbabwe  2016
# 6897     Zimbabwe  2017
# 6898     Zimbabwe  2018
# 6899     Zimbabwe  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                             16.659229
# 1                                             16.765052
# 2                                             16.874469
# 3                                             16.990720
# 4                                             17.112730
# ...                                                 ...
# 6895                                          11.156429
# 6896                                          11.164133
# 6897                                          11.170427
# 6898                                          11.158765
# 6899                                          11.119021
#
# [6900 rows x 3 columns]

# %%
mental_death.isnull().sum()
# Out:
# Entity                                                                         0
# Year                                                                           0
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)    0
# dtype: int64

# %%
countries_c = mental_death['Entity'].unique()
len(countries_c)
# Out:
# 230

# %% [markdown]
# ### Suicide rate

# %%
suicide_rate = pd.read_csv("/content/raw_data/suicide_rate_country_age_standardized.csv")

# %%
# filter only both sexes 
suicide_both_sexes = suicide_rate.loc[suicide_rate['Sex'] == 'Both sexes',:].drop(['Sex'], axis=1)

# %%
suicide_both_sexes.head()
# Out:
#                 Country             2019             2018             2017  \
# 0           Afghanistan    6.0 [3.4-9.9]    5.9 [3.4-9.8]    6.0 [3.4-9.9]
# 3               Albania    3.7 [2.1-5.7]    3.9 [2.2-6.0]    4.1 [2.3-6.3]
# 6               Algeria    2.6 [1.4-4.4]    2.6 [1.4-4.4]    2.5 [1.4-4.4]
# 9                Angola  12.6 [7.7-19.4]  12.4 [7.6-19.0]  12.4 [7.6-18.9]
# 12  Antigua and Barbuda    0.3 [0.2-0.5]    0.3 [0.2-0.5]    0.0 [0.0-0.0]
#
#                2016             2015             2014             2013  \
# 0     6.0 [3.5-9.9]    6.0 [3.5-9.9]    6.0 [3.5-9.9]   6.2 [3.6-10.2]
# 3     4.2 [2.3-6.3]    4.2 [2.3-6.4]    4.5 [2.5-6.7]    4.8 [2.7-7.1]
# 6     2.6 [1.4-4.5]    2.7 [1.5-4.7]    2.8 [1.5-4.8]    2.9 [1.5-5.0]
# 9   12.9 [8.0-19.6]  13.3 [8.3-20.1]  13.1 [8.3-19.8]  14.2 [9.0-21.2]
# 12    0.5 [0.3-0.7]    0.4 [0.3-0.6]    0.4 [0.3-0.6]    0.0 [0.0-0.0]
#
#                2012             2011  ...             2009             2008  \
# 0    6.2 [3.6-10.2]   6.4 [3.8-10.5]  ...   6.8 [4.0-11.1]   7.2 [4.2-11.7]
# 3     4.8 [2.8-7.0]   7.6 [4.7-10.7]  ...   8.0 [4.8-10.8]   8.1 [5.0-10.8]
# 6     2.9 [1.6-5.0]    2.9 [1.6-5.1]  ...    3.2 [1.7-5.6]    3.3 [1.8-5.8]
# 9   14.2 [9.0-21.2]  13.5 [8.6-20.2]  ...  13.6 [8.7-20.5]  15.3 [9.7-23.0]
# 12    0.0 [0.0-0.0]    0.2 [0.1-0.2]  ...    0.0 [0.0-0.0]    0.2 [0.2-0.3]
#
#                2007              2006              2005              2004  \
# 0    7.4 [4.3-12.1]    7.6 [4.4-12.3]    7.6 [4.4-12.3]    7.8 [4.5-12.6]
# 3    8.1 [5.0-10.6]    7.8 [5.0-10.2]    7.7 [4.9-10.0]     4.9 [3.1-6.3]
# 6     3.5 [1.8-6.0]     3.7 [2.0-6.4]     3.8 [2.0-6.6]     4.0 [2.1-6.9]
# 9   15.0 [9.5-22.6]  17.1 [10.8-25.6]  16.3 [10.3-24.4]  17.2 [10.8-25.9]
# 12    0.3 [0.2-0.5]     0.4 [0.3-0.6]     1.3 [0.9-1.8]     2.0 [1.4-2.7]
#
#                 2003              2002              2001              2000
# 0     7.7 [4.5-12.5]    7.9 [4.5-12.8]    7.9 [4.5-12.8]    7.7 [4.4-12.5]
# 3      4.9 [3.3-6.4]     4.8 [3.2-6.3]     4.7 [3.2-6.2]     5.2 [3.6-6.9]
# 6      4.1 [2.2-7.1]     4.4 [2.4-7.6]     4.6 [2.4-7.9]     4.7 [2.5-8.0]
# 9   17.5 [10.8-26.6]  17.2 [10.7-26.3]  17.5 [10.6-26.7]  17.6 [10.5-27.0]
# 12     1.4 [1.0-2.0]     1.3 [0.9-1.7]     1.9 [1.3-2.6]     2.0 [1.4-2.7]
#
# [5 rows x 21 columns]

# %%
cols_drop = []
melts_vars = [["Country"], "Year", "Suicide rate"]

# %%
suicide_both_sexes_final = preprocessing(suicide_both_sexes, cols_drop, melts_vars)

# %%
suicide_both_sexes_final.loc[suicide_both_sexes_final['Country'] == 'Albania',:]
# Out:
#       Country  Year    Suicide rate
# 1     Albania  2019   3.7 [2.1-5.7]
# 184   Albania  2018   3.9 [2.2-6.0]
# 367   Albania  2017   4.1 [2.3-6.3]
# 550   Albania  2016   4.2 [2.3-6.3]
# 733   Albania  2015   4.2 [2.3-6.4]
# 916   Albania  2014   4.5 [2.5-6.7]
# 1099  Albania  2013   4.8 [2.7-7.1]
# 1282  Albania  2012   4.8 [2.8-7.0]
# 1465  Albania  2011  7.6 [4.7-10.7]
# 1648  Albania  2010  7.6 [4.6-10.5]
# 1831  Albania  2009  8.0 [4.8-10.8]
# 2014  Albania  2008  8.1 [5.0-10.8]
# 2197  Albania  2007  8.1 [5.0-10.6]
# 2380  Albania  2006  7.8 [5.0-10.2]
# 2563  Albania  2005  7.7 [4.9-10.0]
# 2746  Albania  2004   4.9 [3.1-6.3]
# 2929  Albania  2003   4.9 [3.3-6.4]
# 3112  Albania  2002   4.8 [3.2-6.3]
# 3295  Albania  2001   4.7 [3.2-6.2]
# 3478  Albania  2000   5.2 [3.6-6.9]

# %%
suicide_both_sexes_final["Year"] = suicide_both_sexes_final["Year"].astype("int64")

# %%
suicide_both_sexes_final.dtypes
# Out:
# Country         object
# Year             int64
# Suicide rate    object
# dtype: object

# %%
suicide_both_sexes_final.isnull().sum()
# Out:
# Country         0
# Year            0
# Suicide rate    0
# dtype: int64

# %%
len(suicide_both_sexes_final['Country'].unique())
# Out:
# 183

# %%
countries_suicide = suicide_both_sexes_final['Country'].unique()

# %%
suicide_both_sexes_final.rename(columns={'Country': 'Entity'}, inplace=True)

# %% [markdown]
# ### Clean

# %%
# only select subset in the available countries from the referenced data
self_harm_death_final = self_harm_death.loc[self_harm_death['Entity'].isin(countries_suicide)]

# %%
len(self_harm_death_final['Entity'].unique())
# Out:
# 164

# %%
self_harm_death_final.isnull().sum()
# Out:
# Entity                                                      0
# Year                                                        0
# Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)    0
# dtype: int64

# %%
mental_substance_final = mental_substance_death_final.loc[mental_substance_death_final['Entity'].isin(countries_suicide)]
print(len(mental_substance_final['Entity'].unique()))
mental_substance_final.isnull().sum()
# Out:
# 164
# Entity                                                                                    0
# Year                                                                                      0
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)    0
# dtype: int64

# %%
mental_death_final = mental_death.loc[mental_death['Entity'].isin(countries_suicide)]
print(len(mental_death_final['Entity'].unique()))
mental_death_final.isnull().sum()
# Out:
# 163
# Entity                                                                         0
# Year                                                                           0
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)    0
# dtype: int64

# %% [markdown]
# ### First Merge

# %% [markdown]
# **=>** Now, we have a set of dataframes with similar stucture to merge.

# %%
# compile the list of dataframes we want to merge
data_frames = [mental_death_final,mental_substance_final, self_harm_death_final, suicide_both_sexes_final]
left_on = ['Entity', 'Year']
right_on = ['Entity', 'Year']
how = 'left'

# %%
first_merged = merge_data(data_frames, left_on, right_on, how)

# %%
first_merged
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 4885     Zimbabwe  2015
# 4886     Zimbabwe  2016
# 4887     Zimbabwe  2017
# 4888     Zimbabwe  2018
# 4889     Zimbabwe  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                             16.659229
# 1                                             16.765052
# 2                                             16.874469
# 3                                             16.990720
# 4                                             17.112730
# ...                                                 ...
# 4885                                          11.156429
# 4886                                          11.164133
# 4887                                          11.170427
# 4888                                          11.158765
# 4889                                          11.119021
#
#       Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                              0.144067
# 1                                              0.140653
# 2                                              0.135279
# 3                                              0.133047
# 4                                              0.130073
# ...                                                 ...
# 4885                                           1.413464
# 4886                                           1.445058
# 4887                                           1.470020
# 4888                                                NaN
# 4889                                                NaN
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)  \
# 0                                              0.381465
# 1                                              0.388646
# 2                                              0.409441
# 3                                              0.418030
# 4                                              0.409779
# ...                                                 ...
# 4885                                           1.676438
# 4886                                           1.747906
# 4887                                           1.804474
# 4888                                           1.870430
# 4889                                           1.893108
#
#           Suicide rate
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4885  30.7 [16.6-48.3]
# 4886  28.7 [15.4-45.3]
# 4887  25.9 [13.8-40.9]
# 4888  23.9 [12.7-37.8]
# 4889  23.6 [12.6-37.5]
#
# [4890 rows x 6 columns]

# %%
first_merged.dtypes
# Out:
# Entity                                                                                     object
# Year                                                                                        int64
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)               float64
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)    float64
# Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)                                  float64
# Suicide rate                                                                               object
# dtype: object

# %%
len(first_merged['Entity'].unique())
# Out:
# 163

# %%
years_keep = list(np.arange(2000,2020))

# %%
first_merged = first_merged.loc[first_merged['Year'].isin(years_keep)]

# %%
first_merged.isnull().sum()
# Out:
# Entity                                                                                      0
# Year                                                                                        0
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)                 0
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)    326
# Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)                                    0
# Suicide rate                                                                                0
# dtype: int64

# %%
# Save first merged to csv file
first_merged.to_csv('./first_merge_data.csv', index=False)

# %% [markdown]
# ## Merge gdp, unemployment rate, and income

# %% [markdown]
# ### GDP (current, per capita)

# %%
gdp_current = pd.read_csv("/content/raw_data/gdp_current.csv")

# %%
cols_drop = ['Country Code', 'Indicator Name', 'Indicator Code']
melts_var = [["Country Name"], "Year", "gdp_current"]

# %%
gdp_current_final = preprocessing(gdp_current, cols_drop, melts_var)

# %%
gdp_current_final
# Out:
#                       Country Name  Year   gdp_current
# 0                            Aruba  1960           NaN
# 1      Africa Eastern and Southern  1960  2.008272e+10
# 2                      Afghanistan  1960  5.377778e+08
# 3       Africa Western and Central  1960  1.040428e+10
# 4                           Angola  1960           NaN
# ...                            ...   ...           ...
# 16487                       Kosovo  2021           NaN
# 16488                  Yemen, Rep.  2021           NaN
# 16489                 South Africa  2021           NaN
# 16490                       Zambia  2021           NaN
# 16491                     Zimbabwe  2021           NaN
#
# [16492 rows x 3 columns]

# %%
gdp_current_final['Year'] = gdp_current_final['Year'].astype("int64")

# %%
gdp_per_capita = pd.read_csv("/content/raw_data/gdp_per_capita.csv")

# %%
cols_drop = ['Country Code', 'Indicator Name', 'Indicator Code']
melts_var = [["Country Name"], "Year", "gdp_per_capita"]

# %%
gdp_per_capita_final = preprocessing(gdp_per_capita, cols_drop, melts_var)

# %%
gdp_per_capita_final
# Out:
#                       Country Name  Year  gdp_per_capita
# 0                            Aruba  1960             NaN
# 1      Africa Eastern and Southern  1960      153.494439
# 2                      Afghanistan  1960       59.773234
# 3       Africa Western and Central  1960      107.932233
# 4                           Angola  1960             NaN
# ...                            ...   ...             ...
# 16487                       Kosovo  2021             NaN
# 16488                  Yemen, Rep.  2021             NaN
# 16489                 South Africa  2021             NaN
# 16490                       Zambia  2021             NaN
# 16491                     Zimbabwe  2021             NaN
#
# [16492 rows x 3 columns]

# %%
gdp_per_capita_final['Year'] = gdp_per_capita_final['Year'].astype("int64")

# %%
gdp_per_capita_final.dtypes
# Out:
# Country Name       object
# Year                int64
# gdp_per_capita    float64
# dtype: object

# %%
gdp_current_final.dtypes
# Out:
# Country Name     object
# Year              int64
# gdp_current     float64
# dtype: object

# %%
gdp_per_capita_final.rename(columns={'Country Name': 'Country'}, inplace=True)
gdp_current_final.rename(columns={'Country Name': 'Country'}, inplace=True)

# %% [markdown]
# ### Unemployment

# %%
unemployment = pd.read_csv("/content/raw_data/unemployment_rate.csv")

# %%
cols_drop = ["Country Code", "Indicator Name", "Indicator Code"]
melts_var = [["Country Name"], "Year", "unemployment rate"]

# %%
unemployment_final = preprocessing(unemployment, cols_drop, melts_var)
unemployment_final
# Out:
#                       Country Name  Year  unemployment rate
# 0                            Aruba  1960                NaN
# 1      Africa Eastern and Southern  1960                NaN
# 2                      Afghanistan  1960                NaN
# 3       Africa Western and Central  1960                NaN
# 4                           Angola  1960                NaN
# ...                            ...   ...                ...
# 16487                       Kosovo  2021                NaN
# 16488                  Yemen, Rep.  2021          13.574000
# 16489                 South Africa  2021          33.558998
# 16490                       Zambia  2021          13.026000
# 16491                     Zimbabwe  2021           5.174000
#
# [16492 rows x 3 columns]

# %%
unemployment_final["Year"] = unemployment_final["Year"].astype("int64")

# %%
unemployment_final.dtypes
# Out:
# Country Name          object
# Year                   int64
# unemployment rate    float64
# dtype: object

# %% [markdown]
# ### Health Expenditure (gdp, per capita)

# %%
expenditure_gdp = pd.read_csv("/content/raw_data/health_expenditure_gdp.csv")

# %%
cols_drop = ["Country Code", "Indicator Name", "Indicator Code"]
melts_vars = [["Country Name"], "Year", "health expenditure (% GDP)"]

# %%
expenditure_gdp_final = preprocessing(expenditure_gdp,cols_drop,melts_vars)

# %%
expenditure_gdp_final.loc[expenditure_gdp_final["Country Name"] == "France"]
# Out:
#       Country Name  Year  health expenditure (% GDP)
# 77          France  1960                         NaN
# 343         France  1961                         NaN
# 609         France  1962                         NaN
# 875         France  1963                         NaN
# 1141        France  1964                         NaN
# ...            ...   ...                         ...
# 15239       France  2017                   11.332762
# 15505       France  2018                   11.185830
# 15771       France  2019                   11.057472
# 16037       France  2020                         NaN
# 16303       France  2021                         NaN
#
# [62 rows x 3 columns]

# %%
expenditure_gdp_final["Year"] = expenditure_gdp_final["Year"].astype("int64")

# %%
expenditure_capita = pd.read_csv("/content/raw_data/health_expenditure_per_capita.csv")

# %%
expenditure_capita
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 1    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 2    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 3    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 4    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# ..                                                 ...                ...
# 261  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 262  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 263  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 264  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 265  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
#
#      1960  1961  1962  1963  1964  1965  ...        2012        2013  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN  ...  113.183637  111.227695
# 2     NaN   NaN   NaN   NaN   NaN   NaN  ...   51.440262   55.034630
# 3     NaN   NaN   NaN   NaN   NaN   NaN  ...   71.039947   78.746863
# 4     NaN   NaN   NaN   NaN   NaN   NaN  ...  122.185585  143.606873
# ..    ...   ...   ...   ...   ...   ...  ...         ...         ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN  ...   75.143700   79.728119
# 263   NaN   NaN   NaN   NaN   NaN   NaN  ...  658.122986  604.769897
# 264   NaN   NaN   NaN   NaN   NaN   NaN  ...   69.295303   88.128204
# 265   NaN   NaN   NaN   NaN   NaN   NaN  ...   90.283081  101.674934
#
#            2014        2015        2016        2017        2018        2019  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1    104.541257   99.008506   94.739159  102.410661   96.289480   91.970113
# 2     59.008934   58.906528   60.188671   65.706024   69.998604   65.806030
# 3     81.804504   73.297775   63.649069   60.968846   59.328810   61.338476
# 4    131.647659  108.582939   95.124977  114.334602   87.310738   71.326004
# ..          ...         ...         ...         ...         ...         ...
# 261         NaN         NaN         NaN         NaN         NaN         NaN
# 262   81.051949   73.176743         NaN         NaN         NaN         NaN
# 263  549.696167  503.759460  465.088104  534.388367  564.503296  546.688416
# 264   67.496788   59.337643   57.362690   67.195236   76.314423   69.324379
# 265  116.710541  107.686999  112.411404  115.646201  141.369308  103.028272
#
#      2020  2021
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# ..    ...   ...
# 261   NaN   NaN
# 262   NaN   NaN
# 263   NaN   NaN
# 264   NaN   NaN
# 265   NaN   NaN
#
# [266 rows x 66 columns]

# %%
cols_drop = ["Country Code", "Indicator Name", "Indicator Code"]
melts_vars = [["Country Name"], "Year", "health expenditure (per capita)"]

# %%
expenditure_capita_final = preprocessing(expenditure_capita, cols_drop, melts_vars)

# %%
expenditure_capita_final
# Out:
#                       Country Name  Year  health expenditure (per capita)
# 0                            Aruba  1960                              NaN
# 1      Africa Eastern and Southern  1960                              NaN
# 2                      Afghanistan  1960                              NaN
# 3       Africa Western and Central  1960                              NaN
# 4                           Angola  1960                              NaN
# ...                            ...   ...                              ...
# 16487                       Kosovo  2021                              NaN
# 16488                  Yemen, Rep.  2021                              NaN
# 16489                 South Africa  2021                              NaN
# 16490                       Zambia  2021                              NaN
# 16491                     Zimbabwe  2021                              NaN
#
# [16492 rows x 3 columns]

# %%
expenditure_capita_final["Year"] = expenditure_capita_final["Year"].astype("int64")

# %%
unemployment_final.rename(columns={'Country Name': 'Country'}, inplace=True)
expenditure_capita_final.rename(columns={'Country Name': 'Country'}, inplace=True)
expenditure_gdp_final.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
expenditure_capita_final.isnull().sum()
# Out:
# Country                                0
# Year                                   0
# health expenditure (per capita)    11798
# dtype: int64

# %%
expenditure_capita_final.loc[expenditure_capita_final['Country']=='Canada']
# Out:
#       Country  Year  health expenditure (per capita)
# 35     Canada  1960                              NaN
# 301    Canada  1961                              NaN
# 567    Canada  1962                              NaN
# 833    Canada  1963                              NaN
# 1099   Canada  1964                              NaN
# ...       ...   ...                              ...
# 15197  Canada  2017                      4865.070801
# 15463  Canada  2018                      5018.711426
# 15729  Canada  2019                      5048.372559
# 15995  Canada  2020                              NaN
# 16261  Canada  2021                              NaN
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Income group

# %%
income = pd.read_csv("/content/raw_data/data_income.csv")

# %%
income.head()
# Out:
#        Country         Income group                     Region  \
# 0        Aruba          High income  Latin America & Caribbean
# 1  Afghanistan           Low income                 South Asia
# 2       Angola  Lower middle income         Sub-Saharan Africa
# 3      Albania  Upper middle income      Europe & Central Asia
# 4      Andorra          High income      Europe & Central Asia
#
#   Lending category   1987     1988     1989     1990     1991     1992  ...  \
# 0              NaN    NaN  10360.0  11760.0  12230.0  13190.0  13990.0  ...
# 1              IDA    NaN      NaN      NaN      NaN      NaN      NaN  ...
# 2             IBRD  670.0    650.0    860.0    780.0   1380.0   1170.0  ...
# 3             IBRD  730.0    730.0    760.0    650.0    410.0    280.0  ...
# 4              NaN    NaN      NaN      NaN      NaN      NaN      NaN  ...
#
#       2011     2012     2013     2014     2015     2016     2017    2018  \
# 0  22450.0  23520.0  24510.0  25350.0  26560.0  26840.0  27120.0     NaN
# 1    530.0    630.0    660.0    630.0    600.0    550.0    530.0   520.0
# 2   3410.0   4170.0   4780.0   5010.0   4520.0   3770.0   3450.0  3210.0
# 3   4410.0   4360.0   4540.0   4540.0   4390.0   4320.0   4290.0  4860.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
#
#      2019    2020
# 0     NaN     NaN
# 1   530.0   500.0
# 2  2970.0  2230.0
# 3  5220.0  5210.0
# 4     NaN     NaN
#
# [5 rows x 38 columns]

# %%
cols_drop = ["Region", "Lending category"]
melts_vars = [["Country","Income group"], "Year", "Income"]

# %%
income_final = preprocessing(income, cols_drop, melts_vars)

# %%
income_final
# Out:
#            Country         Income group  Year  Income
# 0            Aruba          High income  1987     NaN
# 1      Afghanistan           Low income  1987     NaN
# 2           Angola  Lower middle income  1987   670.0
# 3          Albania  Upper middle income  1987   730.0
# 4          Andorra          High income  1987     NaN
# ...            ...                  ...   ...     ...
# 7373        Kosovo  Upper middle income  2020  4440.0
# 7374   Yemen, Rep.           Low income  2020     NaN
# 7375  South Africa  Upper middle income  2020  5410.0
# 7376        Zambia  Lower middle income  2020  1190.0
# 7377      Zimbabwe  Lower middle income  2020  1090.0
#
# [7378 rows x 4 columns]

# %%
income_final["Year"] = income_final["Year"].astype("int64")

# %%
income_final.dtypes
# Out:
# Country          object
# Income group     object
# Year              int64
# Income          float64
# dtype: object

# %% [markdown]
# ### Second merge

# %%
df_merge = [gdp_current_final, gdp_per_capita_final, expenditure_capita_final,expenditure_gdp_final, unemployment_final, income_final]
left_on=['Country', 'Year']
right_on=['Country','Year']
how='left'

# %%
tmp_merge = merge_data(df_merge, left_on, right_on, how)

# %%
years_keep = list(np.arange(2000,2020))

# %%
tmp_merge = tmp_merge.loc[tmp_merge['Year'].isin(years_keep)]

# %%
tmp_merge
# Out:
#                            Country  Year   gdp_current  gdp_per_capita  \
# 10640                        Aruba  2000  1.873453e+09    20617.750470
# 10641  Africa Eastern and Southern  2000  2.839530e+11      713.245921
# 10642                  Afghanistan  2000           NaN             NaN
# 10643   Africa Western and Central  2000  1.404080e+11      525.450343
# 10644                       Angola  2000  9.129635e+09      556.838632
# ...                            ...   ...           ...             ...
# 15955                       Kosovo  2019  7.899879e+09     4416.108358
# 15956                  Yemen, Rep.  2019           NaN             NaN
# 15957                 South Africa  2019  3.879350e+11     6624.761865
# 15958                       Zambia  2019  2.330867e+10     1305.001031
# 15959                     Zimbabwe  2019  1.928429e+10     1316.740657
#
#        health expenditure (per capita)  health expenditure (% GDP)  \
# 10640                              NaN                         NaN
# 10641                        44.195249                    6.252428
# 10642                              NaN                         NaN
# 10643                        20.362792                    3.771294
# 10644                        12.998967                    1.908599
# ...                                ...                         ...
# 15955                              NaN                         NaN
# 15956                              NaN                         NaN
# 15957                       546.688416                    9.109355
# 15958                        69.324379                    5.312203
# 15959                       103.028272                    7.703565
#
#        unemployment rate         Income group   Income
# 10640                NaN          High income  20000.0
# 10641           7.724844                  NaN      NaN
# 10642          10.806000           Low income      NaN
# 10643           4.921423                  NaN      NaN
# 10644           4.030000  Lower middle income    360.0
# ...                  ...                  ...      ...
# 15955                NaN  Upper middle income   4690.0
# 15956          13.056000           Low income      NaN
# 15957          28.469999  Upper middle income   6040.0
# 15958          12.520000  Lower middle income   1430.0
# 15959           4.833000  Lower middle income   1200.0
#
# [5320 rows x 9 columns]

# %%
countries_tmp = ['Bahamas, The','Congo, Rep.','Czech Republic','Egypt, Arab Rep.','Gambia, The','Kyrgyz Republic','St. Lucia','St. Vincent and the Grenadines','Slovak Republic','Yemen, Rep.']

# %%
countries_replace = ['Bahamas','Congo','Czechia','Egypt','Gambia','Kyrgyzstan','Saint Lucia','Saint Vincent and the Grenadines','Slovakia','Yemen']

# %%
# replace country name to match with other dataset
for i, country in enumerate(countries_tmp):
  tmp_merge['Country'].replace({country:countries_replace[i]}, inplace=True)

# %%
tmp_merge
# Out:
#                            Country  Year   gdp_current  gdp_per_capita  \
# 10640                        Aruba  2000  1.873453e+09    20617.750470
# 10641  Africa Eastern and Southern  2000  2.839530e+11      713.245921
# 10642                  Afghanistan  2000           NaN             NaN
# 10643   Africa Western and Central  2000  1.404080e+11      525.450343
# 10644                       Angola  2000  9.129635e+09      556.838632
# ...                            ...   ...           ...             ...
# 15955                       Kosovo  2019  7.899879e+09     4416.108358
# 15956                        Yemen  2019           NaN             NaN
# 15957                 South Africa  2019  3.879350e+11     6624.761865
# 15958                       Zambia  2019  2.330867e+10     1305.001031
# 15959                     Zimbabwe  2019  1.928429e+10     1316.740657
#
#        health expenditure (per capita)  health expenditure (% GDP)  \
# 10640                              NaN                         NaN
# 10641                        44.195249                    6.252428
# 10642                              NaN                         NaN
# 10643                        20.362792                    3.771294
# 10644                        12.998967                    1.908599
# ...                                ...                         ...
# 15955                              NaN                         NaN
# 15956                              NaN                         NaN
# 15957                       546.688416                    9.109355
# 15958                        69.324379                    5.312203
# 15959                       103.028272                    7.703565
#
#        unemployment rate         Income group   Income
# 10640                NaN          High income  20000.0
# 10641           7.724844                  NaN      NaN
# 10642          10.806000           Low income      NaN
# 10643           4.921423                  NaN      NaN
# 10644           4.030000  Lower middle income    360.0
# ...                  ...                  ...      ...
# 15955                NaN  Upper middle income   4690.0
# 15956          13.056000           Low income      NaN
# 15957          28.469999  Upper middle income   6040.0
# 15958          12.520000  Lower middle income   1430.0
# 15959           4.833000  Lower middle income   1200.0
#
# [5320 rows x 9 columns]

# %%
tmp_merge.isnull().sum()
# Out:
# Country                               0
# Year                                  0
# gdp_current                         230
# gdp_per_capita                      230
# health expenditure (per capita)     626
# health expenditure (% GDP)          626
# unemployment rate                   620
# Income group                       1040
# Income                             1514
# dtype: int64

# %%
tmp_merge.rename(columns={'Country': 'Entity'}, inplace=True)

# %%
tmp_merge.to_csv("second_merge_data.csv", index=False)

# %% [markdown]
# ## Merge primary care expenditure, disability

# %% [markdown]
# ### Disability

# %%
disability = pd.read_csv("/content/raw_data/mental-and-substance-use-as-share-of-disease.csv")
disability = disability.drop(columns=['Code'], axis=1)
disability.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %%
disability.dtypes
# Out:
# Entity                                                                                              object
# Year                                                                                                 int64
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)    float64
# dtype: object

# %% [markdown]
# ### Final merge

# %%
data_frames = [first_merged, tmp_merge, disability]
left_on = ['Entity', 'Year']
right_on = ['Entity', 'Year']
how = 'left'

# %%
final_merge = merge_data(data_frames, left_on, right_on, how)

# %%
final_merge.columns
# Out:
# Index(['Entity', 'Year',
#        'Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)',
#        'Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)',
#        'Suicide rate', 'gdp_current', 'gdp_per_capita',
#        'health expenditure (per capita)', 'health expenditure (% GDP)',
#        'unemployment rate', 'Income group', 'Income',
#        'DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)'],
#       dtype='object')

# %%
# reorder columns
cols_order = ['Entity', 'Year',
       'Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)',
       'Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)',
       'Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)',
       'gdp_current', 'gdp_per_capita', 'health expenditure (per capita)',
       'health expenditure (% GDP)', 'unemployment rate', 'Income group',
       'Income',
       'DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)',
       'Suicide rate']

# %%
final_merge = final_merge[cols_order]

# %%
final_merge
# Out:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3255     Zimbabwe  2015
# 3256     Zimbabwe  2016
# 3257     Zimbabwe  2017
# 3258     Zimbabwe  2018
# 3259     Zimbabwe  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                             17.939269
# 1                                             17.933525
# 2                                             17.916547
# 3                                             17.889702
# 4                                             17.859903
# ...                                                 ...
# 3255                                          11.156429
# 3256                                          11.164133
# 3257                                          11.170427
# 3258                                          11.158765
# 3259                                          11.119021
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)  \
# 0                                              0.442532
# 1                                              0.457531
# 2                                              0.461904
# 3                                              0.490590
# 4                                              0.514944
# ...                                                 ...
# 3255                                           1.676438
# 3256                                           1.747906
# 3257                                           1.804474
# 3258                                           1.870430
# 3259                                           1.893108
#
#       Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                              0.090314
# 1                                              0.084862
# 2                                              0.081991
# 3                                              0.081942
# 4                                              0.082468
# ...                                                 ...
# 3255                                           1.413464
# 3256                                           1.445058
# 3257                                           1.470020
# 3258                                                NaN
# 3259                                                NaN
#
#        gdp_current  gdp_per_capita  health expenditure (per capita)  \
# 0              NaN             NaN                              NaN
# 1              NaN             NaN                              NaN
# 2     4.055180e+09      179.426579                        15.803164
# 3     4.515559e+09      190.683814                        17.035744
# 4     5.226779e+09      211.382074                        20.412764
# ...            ...             ...                              ...
# 3255  1.996312e+10     1445.069702                       107.686999
# 3256  2.054868e+10     1464.588957                       112.411404
# 3257  1.758489e+10     1235.189032                       115.646201
# 3258  1.811554e+10     1254.642265                       141.369308
# 3259  1.928429e+10     1316.740657                       103.028272
#
#       health expenditure (% GDP)  unemployment rate         Income group  \
# 0                            NaN             10.806           Low income
# 1                            NaN             10.809           Low income
# 2                       9.443390             11.257           Low income
# 3                       8.941258             11.141           Low income
# 4                       9.808474             10.988           Low income
# ...                          ...                ...                  ...
# 3255                    7.452066              4.778  Lower middle income
# 3256                    7.675163              4.788  Lower middle income
# 3257                    7.469752              4.785  Lower middle income
# 3258                    8.680062              4.796  Lower middle income
# 3259                    7.703565              4.833  Lower middle income
#
#       Income  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 3255  1280.0
# 3256  1290.0
# 3257  1390.0
# 3258  1410.0
# 3259  1200.0
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)  \
# 0                                              1.893882
# 1                                              1.963984
# 2                                              2.090646
# 3                                              2.240707
# 4                                              2.360176
# ...                                                 ...
# 3255                                           2.193166
# 3256                                           2.279813
# 3257                                           2.364265
# 3258                                           2.472949
# 3259                                           2.525892
#
#           Suicide rate
# 0       7.7 [4.4-12.5]
# 1       7.9 [4.5-12.8]
# 2       7.9 [4.5-12.8]
# 3       7.7 [4.5-12.5]
# 4       7.8 [4.5-12.6]
# ...                ...
# 3255  30.7 [16.6-48.3]
# 3256  28.7 [15.4-45.3]
# 3257  25.9 [13.8-40.9]
# 3258  23.9 [12.7-37.8]
# 3259  23.6 [12.6-37.5]
#
# [3260 rows x 14 columns]

# %%
tmp = final_merge['Suicide rate'].str.split('[', 1, expand=True)

# %%
tmp
# Out:
#           0           1
# 0      7.7    4.4-12.5]
# 1      7.9    4.5-12.8]
# 2      7.9    4.5-12.8]
# 3      7.7    4.5-12.5]
# 4      7.8    4.5-12.6]
# ...     ...         ...
# 3255  30.7   16.6-48.3]
# 3256  28.7   15.4-45.3]
# 3257  25.9   13.8-40.9]
# 3258  23.9   12.7-37.8]
# 3259  23.6   12.6-37.5]
#
# [3260 rows x 2 columns]

# %%
final_merge['Suicide rate'] = tmp[0]

# %%
final_merge
# Out:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3255     Zimbabwe  2015
# 3256     Zimbabwe  2016
# 3257     Zimbabwe  2017
# 3258     Zimbabwe  2018
# 3259     Zimbabwe  2019
#
#       Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                             17.939269
# 1                                             17.933525
# 2                                             17.916547
# 3                                             17.889702
# 4                                             17.859903
# ...                                                 ...
# 3255                                          11.156429
# 3256                                          11.164133
# 3257                                          11.170427
# 3258                                          11.158765
# 3259                                          11.119021
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)  \
# 0                                              0.442532
# 1                                              0.457531
# 2                                              0.461904
# 3                                              0.490590
# 4                                              0.514944
# ...                                                 ...
# 3255                                           1.676438
# 3256                                           1.747906
# 3257                                           1.804474
# 3258                                           1.870430
# 3259                                           1.893108
#
#       Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                              0.090314
# 1                                              0.084862
# 2                                              0.081991
# 3                                              0.081942
# 4                                              0.082468
# ...                                                 ...
# 3255                                           1.413464
# 3256                                           1.445058
# 3257                                           1.470020
# 3258                                                NaN
# 3259                                                NaN
#
#        gdp_current  gdp_per_capita  health expenditure (per capita)  \
# 0              NaN             NaN                              NaN
# 1              NaN             NaN                              NaN
# 2     4.055180e+09      179.426579                        15.803164
# 3     4.515559e+09      190.683814                        17.035744
# 4     5.226779e+09      211.382074                        20.412764
# ...            ...             ...                              ...
# 3255  1.996312e+10     1445.069702                       107.686999
# 3256  2.054868e+10     1464.588957                       112.411404
# 3257  1.758489e+10     1235.189032                       115.646201
# 3258  1.811554e+10     1254.642265                       141.369308
# 3259  1.928429e+10     1316.740657                       103.028272
#
#       health expenditure (% GDP)  unemployment rate         Income group  \
# 0                            NaN             10.806           Low income
# 1                            NaN             10.809           Low income
# 2                       9.443390             11.257           Low income
# 3                       8.941258             11.141           Low income
# 4                       9.808474             10.988           Low income
# ...                          ...                ...                  ...
# 3255                    7.452066              4.778  Lower middle income
# 3256                    7.675163              4.788  Lower middle income
# 3257                    7.469752              4.785  Lower middle income
# 3258                    8.680062              4.796  Lower middle income
# 3259                    7.703565              4.833  Lower middle income
#
#       Income  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 3255  1280.0
# 3256  1290.0
# 3257  1390.0
# 3258  1410.0
# 3259  1200.0
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)  \
# 0                                              1.893882
# 1                                              1.963984
# 2                                              2.090646
# 3                                              2.240707
# 4                                              2.360176
# ...                                                 ...
# 3255                                           2.193166
# 3256                                           2.279813
# 3257                                           2.364265
# 3258                                           2.472949
# 3259                                           2.525892
#
#      Suicide rate
# 0            7.7
# 1            7.9
# 2            7.9
# 3            7.7
# 4            7.8
# ...           ...
# 3255        30.7
# 3256        28.7
# 3257        25.9
# 3258        23.9
# 3259        23.6
#
# [3260 rows x 14 columns]

# %%
final_merge.isnull().sum()
# Out:
# Entity                                                                                               0
# Year                                                                                                 0
# Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)                          0
# Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)                                             0
# Deaths - Mental and substance use disorders - Sex: Both - Age: Age-standardized (Rate)             326
# gdp_current                                                                                         37
# gdp_per_capita                                                                                      37
# health expenditure (per capita)                                                                     76
# health expenditure (% GDP)                                                                          76
# unemployment rate                                                                                   80
# Income group                                                                                         0
# Income                                                                                             120
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)      0
# Suicide rate                                                                                         0
# dtype: int64

# %%
final_merge.to_csv("./final_merge_data.csv", index=False)
